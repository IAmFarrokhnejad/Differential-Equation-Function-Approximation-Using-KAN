# %%
# !pip install --upgrade --force-reinstall numpy matplotlib torch pandas pykan jax scikit-learn polars

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from kan import MultKAN

EPOCHS = 300

# Helper function to print comparison table
def print_comparison_table(t_eval_np, y_pred, y_exact_eval, example_number):
    print(f"\nComparison Table for Example {example_number}:")
    print(f"{'t':<10}{'Network Output':<20}{'Exact Solution':<20}")
    print("-" * 50)
    for t, pred, exact in zip(t_eval_np.flatten(), y_pred.flatten(), y_exact_eval.flatten()):
        print(f"{t:<10.4f}{pred:<20.6f}{exact:<20.6f}")


def train_model_with_physics(model, epochs, optimizer, t_train, ode_loss, patience=50):
    # Set model to training mode
    model.train()

    best_loss = float('inf')
    counter = 0
    losses = []

    for epoch in range(epochs):
        def closure():
            optimizer.zero_grad()

            # Get model prediction (z(t))
            z_pred = model(t_train)

            # Calculate loss using ode_loss(t, z) function
            total_loss = ode_loss(t_train, z_pred)
            total_loss.backward()
            return total_loss

        loss = optimizer.step(closure)

        if loss.item() < best_loss:
            best_loss = loss.item()
            counter = 0
        else:
            counter += 1
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            break

        # Log and store loss
        if epoch % 10 == 0:
            print(f"Epoch {epoch}/{epochs}, Loss: {loss.item()}")
        losses.append(loss.item())

    # Plot loss curve
    plt.plot(losses)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training Loss Curve')
    plt.grid(True)
    plt.show()

    return model

def solve_example1(architecture):
    # Initial condition values (y(a) = A | y(0) = 1)
    A = 1
    a = 0

    # Define model
    model = MultKAN(width=architecture, grid=25, k=3, device='cpu')

    # Function for calculating loss
    # dy(t)/dt = f(t,y); => yt(t) = A + (t-a)z(t); z(t) - model output
    # Error = ((dyt(t)/dt - f(t,y))**2)/2
    def ode_loss(t, z):
        # Compute trial solution y
        y = A + (t - a) * z

        # Calculate dz(t)/dt using autograd
        dz_dt = torch.autograd.grad(z, t, grad_outputs=torch.ones_like(z), create_graph=True)[0]

        # Substitute into dy/dt = z(t) + (t - a) * dz(t)/dt
        dy_dt = z + (t - a) * dz_dt

        # Formulate the residual with dy/dt_actual
        f_term = (t + ((1 + 3 * t**2) / (1 + t + t**3))) * y
        g_term = 2 * t + t**3 + t**2 * ((1 + 3 * t**2) / (1 + t + t**3))
        return torch.mean(((dy_dt - (g_term - f_term))**2))/2

    # Training data
    t_train = torch.linspace(0, 1, 100).reshape(-1, 1).requires_grad_()

    # Define optimizer
    optimizer = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=20, tolerance_grad=1e-7, tolerance_change=1e-9, history_size=50)

    # Train model
    model = train_model_with_physics(model, epochs=EPOCHS, optimizer=optimizer, t_train=t_train, ode_loss=ode_loss)

    # Evaluate and plot
    t_eval = torch.linspace(0, 1, 100).reshape(-1, 1).requires_grad_()
    y_pred = A + (t_eval - a) * model(t_eval).detach()
    y_pred = y_pred.detach().numpy()
    t_eval_np = t_eval.detach().numpy()
    y_exact_eval = (np.exp(-t_eval_np**2 / 2) + t_eval_np**5 + t_eval_np**3 + t_eval_np**2) / (t_eval_np**3 + t_eval_np + 1)

    # Display Results and Comparison
    print(f"MSE for example 1: {(torch.sum((torch.tensor(y_exact_eval) - y_pred)**2))/200}")
    print(f"MAE for example 1: {(torch.sum((torch.abs(torch.tensor(y_exact_eval) - y_pred))))/200}")
    print_comparison_table(t_eval_np, y_pred, y_exact_eval, 1)

    return t_eval_np, y_pred, y_exact_eval

def solve_example2(architecture):
    # Initial condition values (y(a) = A | y(0) = 3)
    A = 3
    a = 0

    # Define model
    model = MultKAN(width=architecture, grid=25, k=3, device='cpu')

    # Function for calculating loss
    # dy(t)/dt = f(t,y); => yt(t) = A + (t-a)z(t); z(t) - model output
    # Error = ((dyt(t)/dt - f(t,y))**2)/2
    def ode_loss(t, z):
        # Compute trial solution y
        y = A + (t - a) * z

        # Calculate dz(t)/dt using autograd
        dz_dt = torch.autograd.grad(z, t, grad_outputs=torch.ones_like(z), create_graph=True)[0]

        # Substitute into dy/dt = z(t) + (t - a) * dz(t)/dt
        dy_dt = z + (t - a) * dz_dt

        # Formulate the residual with dy/dt_actual
        f_term = 2 * y
        g_term = torch.cos(4 * t)
        return torch.mean(((dy_dt - (g_term - f_term))**2))/2

    # Training data
    t_train = torch.linspace(0, 3, 150).reshape(-1, 1).requires_grad_()

    # Define optimizer
    optimizer = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=20, tolerance_grad=1e-7, tolerance_change=1e-9, history_size=50)

    # Train model
    model = train_model_with_physics(model, epochs=EPOCHS, optimizer=optimizer, t_train=t_train, ode_loss=ode_loss)

    # Evaluate and plot
    t_eval = torch.linspace(0, 3, 150).reshape(-1, 1).requires_grad_()
    y_pred = A + (t_eval - a) * model(t_eval).detach()
    y_pred = y_pred.detach().numpy()
    t_eval_np = t_eval.detach().numpy()
    y_exact_eval = (np.sin(4 * t_eval_np) / 5 + np.cos(4 * t_eval_np) / 10 + 2.9 * np.exp(-2 * t_eval_np))

    # Display Results and Comparison
    print(f"MSE for example 2: {(torch.sum((torch.tensor(y_exact_eval) - y_pred)**2))/200}")
    print(f"MAE for example 2: {(torch.sum((torch.abs(torch.tensor(y_exact_eval) - y_pred))))/200}")
    print_comparison_table(t_eval_np, y_pred, y_exact_eval, 2)

    return t_eval_np, y_pred, y_exact_eval

def solve_example3(architecture):
    # Initial condition values (y(a) = A | y(0) = 0.5)
    A = 0.5
    a = 0

    # Define model
    model = MultKAN(width=architecture, grid=25, k=3, device='cpu')

    # Function for calculating loss
    # dy(t)/dt = f(t,y); => yt(t) = A + (t-a)z(t); z(t) - model output
    # Error = ((dyt(t)/dt - f(t,y))**2)/2
    def ode_loss(t, z):
        # Compute trial solution y
        y = A + (t - a) * z

        # Calculate dz(t)/dt using autograd
        dz_dt = torch.autograd.grad(z, t, grad_outputs=torch.ones_like(z), create_graph=True)[0]

        # Substitute into dy/dt = z(t) + (t - a) * dz(t)/dt
        dy_dt = z + (t - a) * dz_dt

        # Formulate the residual with dy/dt_actual
        f_term = y - t**2 + 1
        return torch.mean(((dy_dt - f_term)**2))/2

    # Training data
    t_train = torch.linspace(0, 1, 100).reshape(-1, 1).requires_grad_()

    # Define optimizer
    optimizer = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=20, tolerance_grad=1e-7, tolerance_change=1e-9, history_size=50)

    # Train model
    model = train_model_with_physics(model, epochs=EPOCHS, optimizer=optimizer, t_train=t_train, ode_loss=ode_loss)

    # Evaluate and plot
    t_eval = torch.linspace(0, 1, 100).reshape(-1, 1).requires_grad_()
    y_pred = A + (t_eval - a) * model(t_eval).detach()
    y_pred = y_pred.detach().numpy()
    t_eval_np = t_eval.detach().numpy()
    y_exact_eval = (t_eval_np + 1)**2 - 0.5 * np.exp(t_eval_np)

    # Display Results and Comparison
    print(f"MSE for example 3: {(torch.sum((torch.tensor(y_exact_eval) - y_pred)**2))/200}")
    print(f"MAE for example 3: {(torch.sum((torch.abs(torch.tensor(y_exact_eval) - y_pred))))/200}")
    print_comparison_table(t_eval_np, y_pred, y_exact_eval, 2)

    return t_eval_np, y_pred, y_exact_eval

def plot_results(t1, y1, y1_exact, t2, y2, y2_exact, t3, y3, y3_exact, architecture):
    print("Results for architecture: ", architecture)
    plt.figure(figsize=(18, 5))

    # Plot Example 1
    plt.subplot(1, 3, 1)
    plt.plot(t1, y1, 'b-', label='KAN Solution')
    plt.plot(t1, y1_exact, 'g--', label='Exact Solution')
    plt.title('Example 1: Solution')
    plt.xlabel('t')
    plt.ylabel('y(t)')
    plt.grid(True)
    plt.legend()

    # Plot Example 2
    plt.subplot(1, 3, 2)
    plt.plot(t2, y2, 'r-', label='KAN Solution')
    plt.plot(t2, y2_exact, 'g--', label='Exact Solution')
    plt.title('Example 2: Solution')
    plt.xlabel('t')
    plt.ylabel('y(t)')
    plt.grid(True)
    plt.legend()

    # Plot Example 3
    plt.subplot(1, 3, 3)
    plt.plot(t3, y3, 'm-', label='KAN Solution')
    plt.plot(t3, y3_exact, 'c--', label='Exact Solution')
    plt.title('Example 3: Solution')
    plt.xlabel('t')
    plt.ylabel('y(t)')
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

def main():
    architectures = [
        [1, 20, 1],
        [1, 20, 10, 1],
        [1, 20, 10, 10, 1],
        [1, [20, 10], 1],
        [1, [20, 10], 10, 1],
        [1, [20, 10], 20, 1],
        [1, [20, 10], [10, 20], 1],
        [1, [20, 10, 10], 10, 1],
        [1, [20, 10, 10], 20, 1],
        [1, [20, 10, 10], [20, 10], 1],
        [1, [20, 10, 10], [10, 20], 1],
        [1, [20, 10, 10], [10, 20, 10], [10, 10, 20], 1],
    ]
    for architecture in architectures:
        print("Solving Example 1...")
        t1, y1, y1_exact = solve_example1(architecture)

        print("Solving Example 2...")
        t2, y2, y2_exact = solve_example2(architecture)

        print("Solving Example 3...")
        t3, y3, y3_exact = solve_example3(architecture)

        print("Plotting results...")
        plot_results(t1, y1, y1_exact, t2, y2, y2_exact, t3, y3, y3_exact, architecture)


if __name__ == "__main__":
    main()
# Out:
# Solving Example 1...
# checkpoint directory created: ./model
# saving model version 0.0
# Epoch 0/300, Loss: 0.3232226073741913
# Epoch 10/300, Loss: 0.0016660159453749657
# Epoch 20/300, Loss: 5.332144064595923e-05
# Epoch 30/300, Loss: 1.8090154298988637e-06
# Epoch 40/300, Loss: 8.823037092042796e-07
# Epoch 50/300, Loss: 8.737640655454015e-07
# Epoch 60/300, Loss: 8.667144584251218e-07
# Epoch 70/300, Loss: 8.60904776800453e-07
# Epoch 80/300, Loss: 8.560875244256749e-07
# Epoch 90/300, Loss: 8.520049732396728e-07
# Epoch 100/300, Loss: 8.485840226057917e-07
# Epoch 110/300, Loss: 8.456665909761796e-07
# Epoch 120/300, Loss: 8.431514402218454e-07
# Epoch 130/300, Loss: 8.409828069488867e-07
# Epoch 140/300, Loss: 8.390953212256136e-07
# Epoch 150/300, Loss: 8.374408935196698e-07
# Epoch 160/300, Loss: 8.359672847291222e-07
# Epoch 170/300, Loss: 8.346719369001221e-07
# Epoch 180/300, Loss: 8.335041457030457e-07
# Epoch 190/300, Loss: 8.32483863177913e-07
# Epoch 200/300, Loss: 8.315587365359534e-07
# Epoch 210/300, Loss: 8.306924428325146e-07
# Epoch 220/300, Loss: 8.298947022922221e-07
# Epoch 230/300, Loss: 8.291728477161087e-07
# Epoch 240/300, Loss: 8.2852011473733e-07
# Epoch 250/300, Loss: 8.279114922515873e-07
# Epoch 260/300, Loss: 8.273587468465848e-07
# Epoch 270/300, Loss: 8.268356737062277e-07
# Epoch 280/300, Loss: 8.263611448455777e-07
# Epoch 290/300, Loss: 8.25883205379796e-07
# <ipython-input-1-61cd00510e93>:106: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"MSE for example 1: {(torch.sum((torch.tensor(y_exact_eval) - y_pred)**2))/200}")
# <ipython-input-1-61cd00510e93>:107: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"MAE for example 1: {(torch.sum((torch.abs(torch.tensor(y_exact_eval) - y_pred))))/200}")
# MSE for example 1: 4.5407169690925286e-10
# MAE for example 1: 1.3289153685036581e-05
#
# Comparison Table for Example 1:
# t         Network Output      Exact Solution
# --------------------------------------------------
# 0.0000    1.000000            1.000000
# 0.0101    0.990039            0.990051
# 0.0202    0.980339            0.980398
# 0.0303    0.970961            0.971035
# 0.0404    0.961905            0.961952
# 0.0505    0.953128            0.953144
# 0.0606    0.944602            0.944603
# 0.0707    0.936315            0.936323
# 0.0808    0.928271            0.928298
# 0.0909    0.920476            0.920523
# 0.1010    0.912937            0.912993
# 0.1111    0.905653            0.905704
# 0.1212    0.898616            0.898652
# 0.1313    0.891812            0.891833
# 0.1414    0.885226            0.885244
# 0.1515    0.878855            0.878881
# 0.1616    0.872701            0.872743
# 0.1717    0.866773            0.866826
# 0.1818    0.861077            0.861129
# 0.1919    0.855611            0.855650
# 0.2020    0.850358            0.850387
# 0.2121    0.845301            0.845340
# 0.2222    0.840457            0.840507
# 0.2323    0.835839            0.835887
# 0.2424    0.831447            0.831480
# 0.2525    0.827261            0.827285
# 0.2626    0.823268            0.823303
# 0.2727    0.819483            0.819534
# 0.2828    0.815927            0.815977
# 0.2929    0.812604            0.812633
# 0.3030    0.809481            0.809504
# 0.3131    0.806560            0.806589
# 0.3232    0.803853            0.803889
# 0.3333    0.801367            0.801406
# 0.3434    0.799105            0.799140
# 0.3535    0.797058            0.797094
# 0.3636    0.795228            0.795268
# 0.3737    0.793631            0.793664
# 0.3838    0.792256            0.792284
# 0.3939    0.791096            0.791128
# 0.4040    0.790166            0.790200
# 0.4141    0.789467            0.789501
# 0.4242    0.789001            0.789032
# 0.4343    0.788770            0.788796
# 0.4444    0.788766            0.788794
# 0.4545    0.788993            0.789030
# 0.4646    0.789466            0.789504
# 0.4747    0.790188            0.790219
# 0.4848    0.791155            0.791177
# 0.4949    0.792358            0.792381
# 0.5051    0.793800            0.793831
# 0.5152    0.795495            0.795532
# 0.5253    0.797453            0.797483
# 0.5354    0.799666            0.799689
# 0.5455    0.802127            0.802150
# 0.5556    0.804844            0.804870
# 0.5657    0.807822            0.807849
# 0.5758    0.811062            0.811090
# 0.5859    0.814569            0.814596
# 0.5960    0.818344            0.818367
# 0.6061    0.822384            0.822406
# 0.6162    0.826690            0.826715
# 0.6263    0.831270            0.831296
# 0.6364    0.836126            0.836150
# 0.6465    0.841258            0.841278
# 0.6566    0.846667            0.846684
# 0.6667    0.852352            0.852367
# 0.6768    0.858309            0.858331
# 0.6869    0.864547            0.864575
# 0.6970    0.871074            0.871102
# 0.7071    0.877888            0.877913
# 0.7172    0.884989            0.885008
# 0.7273    0.892377            0.892390
# 0.7374    0.900050            0.900060
# 0.7475    0.908004            0.908017
# 0.7576    0.916238            0.916264
# 0.7677    0.924775            0.924801
# 0.7778    0.933618            0.933629
# 0.7879    0.942748            0.942749
# 0.7980    0.952148            0.952161
# 0.8081    0.961835            0.961866
# 0.8182    0.971830            0.971864
# 0.8283    0.982141            0.982156
# 0.8384    0.992749            0.992742
# 0.8485    1.003613            1.003622
# 0.8586    1.014769            1.014798
# 0.8687    1.026238            1.026268
# 0.8788    1.038018            1.038033
# 0.8889    1.050094            1.050093
# 0.8990    1.062452            1.062448
# 0.9091    1.075090            1.075098
# 0.9192    1.088019            1.088043
# 0.9293    1.101267            1.101282
# 0.9394    1.114807            1.114816
# 0.9495    1.128636            1.128643
# 0.9596    1.142758            1.142765
# 0.9697    1.157167            1.157179
# 0.9798    1.171865            1.171886
# 0.9899    1.186872            1.186886
# 1.0000    1.202177            1.202177
# Solving Example 2...
# checkpoint directory created: ./model
# saving model version 0.0
# Epoch 0/300, Loss: 17.015708923339844
# Epoch 10/300, Loss: 0.36795979738235474
# Epoch 20/300, Loss: 0.018869472667574883
# Epoch 30/300, Loss: 0.0010173509363085032
# Epoch 40/300, Loss: 0.00012866045290138572
# Epoch 50/300, Loss: 2.811842023220379e-05
# Epoch 60/300, Loss: 1.5941539459163323e-05
# Epoch 70/300, Loss: 1.153003267972963e-05
# Epoch 80/300, Loss: 1.064524803950917e-05
# Epoch 90/300, Loss: 1.0630239557940513e-05
# Epoch 100/300, Loss: 1.061931106960401e-05
# Epoch 110/300, Loss: 1.0613069207465742e-05
# Epoch 120/300, Loss: 1.0608674529066775e-05
# Epoch 130/300, Loss: 1.060328031599056e-05
# Epoch 140/300, Loss: 1.0599691449897364e-05
# Epoch 150/300, Loss: 1.0596643733151723e-05
# Epoch 160/300, Loss: 1.0593911611067597e-05
# Epoch 170/300, Loss: 1.0591601494525094e-05
# Epoch 180/300, Loss: 1.0589445992081892e-05
# Epoch 190/300, Loss: 1.0587854376353789e-05
# Epoch 200/300, Loss: 1.0586615644569974e-05
# Epoch 210/300, Loss: 1.0584805750113446e-05
# Epoch 220/300, Loss: 1.0583681614662055e-05
# Epoch 230/300, Loss: 1.0582785762380809e-05
# Epoch 240/300, Loss: 1.0581303286016919e-05
# Epoch 250/300, Loss: 1.05808830994647e-05
# Epoch 260/300, Loss: 1.0579978152236436e-05
# Epoch 270/300, Loss: 1.0579507943475619e-05
# Epoch 280/300, Loss: 1.0578177352726925e-05
# Epoch 290/300, Loss: 1.0577124157862272e-05
# <ipython-input-1-61cd00510e93>:155: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"MSE for example 2: {(torch.sum((torch.tensor(y_exact_eval) - y_pred)**2))/200}")
# <ipython-input-1-61cd00510e93>:156: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"MAE for example 2: {(torch.sum((torch.abs(torch.tensor(y_exact_eval) - y_pred))))/200}")
# MSE for example 2: 1.2043253505567009e-08
# MAE for example 2: 6.688760913675651e-05
#
# Comparison Table for Example 2:
# t         Network Output      Exact Solution
# --------------------------------------------------
# 0.0000    3.000000            3.000000
# 0.0201    2.900867            2.901307
# 0.0403    2.805976            2.806382
# 0.0604    2.714797            2.714947
# 0.0805    2.626414            2.626742
# 0.1007    2.541043            2.541514
# 0.1208    2.458717            2.459027
# 0.1409    2.378919            2.379057
# 0.1611    2.301125            2.301394
# 0.1812    2.225441            2.225842
# 0.2013    2.151934            2.152218
# 0.2215    2.080193            2.080355
# 0.2416    2.009880            2.010097
# 0.2617    1.941000            1.941305
# 0.2819    1.873586            1.873853
# 0.3020    1.807432            1.807627
# 0.3221    1.742362            1.742530
# 0.3423    1.678286            1.678477
# 0.3624    1.615167            1.615395
# 0.3826    1.553003            1.553226
# 0.4027    1.491738            1.491924
# 0.4228    1.431322            1.431454
# 0.4430    1.371660            1.371794
# 0.4631    1.312727            1.312932
# 0.4832    1.254670            1.254867
# 0.5034    1.197481            1.197609
# 0.5235    1.140980            1.141176
# 0.5436    1.085456            1.085593
# 0.5638    1.030711            1.030898
# 0.5839    0.976912            0.977130
# 0.6040    0.924309            0.924339
# 0.6242    0.872432            0.872578
# 0.6443    0.821712            0.821905
# 0.6644    0.772265            0.772382
# 0.6846    0.723979            0.724076
# 0.7047    0.676935            0.677053
# 0.7248    0.631289            0.631383
# 0.7450    0.587021            0.587134
# 0.7651    0.544325            0.544377
# 0.7852    0.503108            0.503178
# 0.8054    0.463598            0.463605
# 0.8255    0.425720            0.425722
# 0.8456    0.389484            0.389587
# 0.8658    0.355180            0.355258
# 0.8859    0.322694            0.322787
# 0.9060    0.292150            0.292219
# 0.9262    0.263483            0.263595
# 0.9463    0.236867            0.236949
# 0.9664    0.212245            0.212308
# 0.9866    0.189611            0.189693
# 1.0067    0.169043            0.169115
# 1.0268    0.150503            0.150579
# 1.0470    0.133957            0.134082
# 1.0671    0.119518            0.119611
# 1.0872    0.107123            0.107145
# 1.1074    0.096567            0.096657
# 1.1275    0.088007            0.088108
# 1.1477    0.081404            0.081453
# 1.1678    0.076626            0.076637
# 1.1879    0.073562            0.073598
# 1.2081    0.072170            0.072266
# 1.2282    0.072459            0.072565
# 1.2483    0.074428            0.074407
# 1.2685    0.077733            0.077704
# 1.2886    0.082293            0.082355
# 1.3087    0.088173            0.088259
# 1.3289    0.095247            0.095306
# 1.3490    0.103400            0.103384
# 1.3691    0.112449            0.112373
# 1.3893    0.122183            0.122155
# 1.4094    0.132539            0.132604
# 1.4295    0.143485            0.143597
# 1.4497    0.154916            0.155006
# 1.4698    0.166672            0.166704
# 1.4899    0.178582            0.178565
# 1.5101    0.190480            0.190462
# 1.5302    0.202280            0.202271
# 1.5503    0.213837            0.213870
# 1.5705    0.225090            0.225141
# 1.5906    0.235893            0.235969
# 1.6107    0.246163            0.246243
# 1.6309    0.255820            0.255859
# 1.6510    0.264690            0.264716
# 1.6711    0.272702            0.272723
# 1.6913    0.279791            0.279792
# 1.7114    0.285838            0.285847
# 1.7315    0.290746            0.290814
# 1.7517    0.294518            0.294633
# 1.7718    0.297147            0.297249
# 1.7919    0.298563            0.298618
# 1.8121    0.298713            0.298703
# 1.8322    0.297490            0.297479
# 1.8523    0.294872            0.294928
# 1.8725    0.290963            0.291044
# 1.8926    0.285797            0.285829
# 1.9128    0.279257            0.279294
# 1.9329    0.271416            0.271462
# 1.9530    0.262345            0.262361
# 1.9732    0.252023            0.252033
# 1.9933    0.240470            0.240525
# 2.0134    0.227794            0.227895
# 2.0336    0.214168            0.214206
# 2.0537    0.199565            0.199531
# 2.0738    0.183990            0.183949
# 2.0940    0.167565            0.167545
# 2.1141    0.150417            0.150413
# 2.1342    0.132646            0.132648
# 2.1544    0.114335            0.114352
# 2.1745    0.095610            0.095631
# 2.1946    0.076575            0.076594
# 2.2148    0.057307            0.057352
# 2.2349    0.037958            0.038019
# 2.2550    0.018684            0.018707
# 2.2752    -0.000421           -0.000466
# 2.2953    -0.019297           -0.019389
# 2.3154    -0.037855           -0.037948
# 2.3356    -0.055976           -0.056031
# 2.3557    -0.073535           -0.073531
# 2.3758    -0.090401           -0.090343
# 2.3960    -0.106448           -0.106366
# 2.4161    -0.121582           -0.121505
# 2.4362    -0.135708           -0.135669
# 2.4564    -0.148752           -0.148774
# 2.4765    -0.160652           -0.160741
# 2.4966    -0.171396           -0.171500
# 2.5168    -0.180924           -0.180988
# 2.5369    -0.189152           -0.189150
# 2.5570    -0.195995           -0.195938
# 2.5772    -0.201366           -0.201315
# 2.5973    -0.205274           -0.205251
# 2.6174    -0.207752           -0.207726
# 2.6376    -0.208754           -0.208729
# 2.6577    -0.208271           -0.208259
# 2.6779    -0.206325           -0.206324
# 2.6980    -0.202940           -0.202939
# 2.7181    -0.198141           -0.198133
# 2.7383    -0.191961           -0.191940
# 2.7584    -0.184371           -0.184404
# 2.7785    -0.175492           -0.175578
# 2.7987    -0.165464           -0.165524
# 2.8188    -0.154302           -0.154309
# 2.8389    -0.142056           -0.142010
# 2.8591    -0.128787           -0.128710
# 2.8792    -0.114558           -0.114499
# 2.8993    -0.099446           -0.099471
# 2.9195    -0.083690           -0.083727
# 2.9396    -0.067427           -0.067371
# 2.9597    -0.050629           -0.050514
# 2.9799    -0.033292           -0.033265
# 3.0000    -0.015698           -0.015741
# Solving Example 3...
# checkpoint directory created: ./model
# saving model version 0.0
# Epoch 0/300, Loss: 0.7107687592506409
# Epoch 10/300, Loss: 0.0004948735586367548
# Epoch 20/300, Loss: 4.528837962425314e-06
# Epoch 30/300, Loss: 9.401092597727256e-07
# Epoch 40/300, Loss: 9.278753054786648e-07
# Epoch 50/300, Loss: 9.204938464790757e-07
# Epoch 60/300, Loss: 9.144085879597696e-07
# Epoch 70/300, Loss: 9.093977269003517e-07
# Epoch 80/300, Loss: 9.052242830875912e-07
# Epoch 90/300, Loss: 9.017376783049258e-07
# Epoch 100/300, Loss: 8.987866522147669e-07
# Epoch 110/300, Loss: 8.962917945609661e-07
# Epoch 120/300, Loss: 8.942135991674149e-07
# Epoch 130/300, Loss: 8.924174608182511e-07
# Epoch 140/300, Loss: 8.90868534497713e-07
# Epoch 150/300, Loss: 8.895027576727443e-07
# Epoch 160/300, Loss: 8.883127975423122e-07
# Epoch 170/300, Loss: 8.872850116858899e-07
# Epoch 180/300, Loss: 8.86344480477419e-07
# Epoch 190/300, Loss: 8.855303690324945e-07
# Epoch 200/300, Loss: 8.848168135955348e-07
# Epoch 210/300, Loss: 8.841967655826011e-07
# Epoch 220/300, Loss: 8.836037750370451e-07
# Epoch 230/300, Loss: 8.830963906802936e-07
# Epoch 240/300, Loss: 8.825693385006161e-07
# Epoch 250/300, Loss: 8.821182291285368e-07
# Epoch 260/300, Loss: 8.817042385089735e-07
# Epoch 270/300, Loss: 8.813061072032724e-07
# Epoch 280/300, Loss: 8.809414566712803e-07
# Epoch 290/300, Loss: 8.806709388409217e-07
# <ipython-input-1-61cd00510e93>:203: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"MSE for example 3: {(torch.sum((torch.tensor(y_exact_eval) - y_pred)**2))/200}")
# <ipython-input-1-61cd00510e93>:204: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"MAE for example 3: {(torch.sum((torch.abs(torch.tensor(y_exact_eval) - y_pred))))/200}")
# MSE for example 3: 6.095572047115638e-09
# MAE for example 3: 5.1414372137514874e-05
#
# Comparison Table for Example 2:
# t         Network Output      Exact Solution
# --------------------------------------------------
# 0.0000    0.500000            0.500000
# 0.0101    0.515256            0.515228
# 0.0202    0.530687            0.530609
# 0.0303    0.546233            0.546141
# 0.0404    0.561892            0.561825
# 0.0505    0.577694            0.577660
# 0.0606    0.593660            0.593645
# 0.0707    0.609796            0.609780
# 0.0808    0.626099            0.626065
# 0.0909    0.642554            0.642498
# 0.1010    0.659149            0.659079
# 0.1111    0.675875            0.675808
# 0.1212    0.692738            0.692685
# 0.1313    0.709754            0.709707
# 0.1414    0.726923            0.726875
# 0.1515    0.744241            0.744189
# 0.1616    0.761705            0.761648
# 0.1717    0.779313            0.779250
# 0.1818    0.797061            0.796996
# 0.1919    0.814951            0.814885
# 0.2020    0.832981            0.832916
# 0.2121    0.851151            0.851089
# 0.2222    0.869464            0.869403
# 0.2323    0.887923            0.887857
# 0.2424    0.906523            0.906451
# 0.2525    0.925262            0.925183
# 0.2626    0.944135            0.944055
# 0.2727    0.963143            0.963064
# 0.2828    0.982286            0.982210
# 0.2929    1.001565            1.001492
# 0.3030    1.020983            1.020910
# 0.3131    1.040537            1.040463
# 0.3232    1.060227            1.060151
# 0.3333    1.080051            1.079972
# 0.3434    1.100011            1.099925
# 0.3535    1.120102            1.120011
# 0.3636    1.140322            1.140229
# 0.3737    1.160668            1.160577
# 0.3838    1.181142            1.181055
# 0.3939    1.201745            1.201662
# 0.4040    1.222479            1.222397
# 0.4141    1.243343            1.243260
# 0.4242    1.264336            1.264251
# 0.4343    1.285458            1.285367
# 0.4444    1.306707            1.306608
# 0.4545    1.328080            1.327974
# 0.4646    1.349571            1.349464
# 0.4747    1.371180            1.371076
# 0.4848    1.392910            1.392811
# 0.4949    1.414762            1.414666
# 0.5051    1.436738            1.436642
# 0.5152    1.458836            1.458738
# 0.5253    1.481058            1.480953
# 0.5354    1.503398            1.503285
# 0.5455    1.525849            1.525733
# 0.5556    1.548409            1.548299
# 0.5657    1.571084            1.570979
# 0.5758    1.593879            1.593773
# 0.5859    1.616791            1.616681
# 0.5960    1.639815            1.639701
# 0.6061    1.662950            1.662833
# 0.6162    1.686195            1.686075
# 0.6263    1.709549            1.709427
# 0.6364    1.733011            1.732888
# 0.6465    1.756580            1.756455
# 0.6566    1.780255            1.780130
# 0.6667    1.804034            1.803911
# 0.6768    1.827918            1.827796
# 0.6869    1.851907            1.851785
# 0.6970    1.876002            1.875877
# 0.7071    1.900203            1.900069
# 0.7172    1.924507            1.924363
# 0.7273    1.948903            1.948757
# 0.7374    1.973384            1.973248
# 0.7475    1.997955            1.997837
# 0.7576    2.022634            2.022523
# 0.7677    2.047439            2.047304
# 0.7778    2.072346            2.072179
# 0.7879    2.097321            2.097147
# 0.7980    2.122357            2.122207
# 0.8081    2.147478            2.147357
# 0.8182    2.172713            2.172597
# 0.8283    2.198056            2.197926
# 0.8384    2.223493            2.223342
# 0.8485    2.249005            2.248844
# 0.8586    2.274588            2.274431
# 0.8687    2.300246            2.300102
# 0.8788    2.325993            2.325854
# 0.8889    2.351835            2.351688
# 0.8990    2.377755            2.377603
# 0.9091    2.403750            2.403596
# 0.9192    2.429828            2.429666
# 0.9293    2.455975            2.455812
# 0.9394    2.482176            2.482034
# 0.9495    2.508489            2.508328
# 0.9596    2.534876            2.534695
# 0.9697    2.561306            2.561134
# 0.9798    2.587792            2.587641
# 0.9899    2.614377            2.614216
# 1.0000    2.641059            2.640859
# Plotting results...
# Results for architecture:  [[1, 0], [20, 0], [1, 0]]
# Solving Example 1...
# checkpoint directory created: ./model
# saving model version 0.0
# Epoch 0/300, Loss: 0.37033793330192566
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-61cd00510e93> in <cell line: 275>()
#     274
#     275 if __name__ == "__main__":
# --> 276     main()
#
# <ipython-input-1-61cd00510e93> in main()
#     261     for architecture in architectures:
#     262         print("Solving Example 1...")
# --> 263         t1, y1, y1_exact = solve_example1(architecture)
#     264
#     265         print("Solving Example 2...")
#
# <ipython-input-1-61cd00510e93> in solve_example1(architecture)
#      94
#      95     # Train model
# ---> 96     model = train_model_with_physics(model, epochs=EPOCHS, optimizer=optimizer, t_train=t_train, ode_loss=ode_loss)
#      97
#      98     # Evaluate and plot
#
# <ipython-input-1-61cd00510e93> in train_model_with_physics(model, epochs, optimizer, t_train, ode_loss, patience)
#      35             return total_loss
#      36
# ---> 37         loss = optimizer.step(closure)
#      38
#      39         if loss.item() < best_loss:
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     485                             )
#     486
# --> 487                 out = func(*args, **kwargs)
#     488                 self._optimizer_step_code()
#     489
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/lbfgs.py in step(self, closure)
#     455                     # no use to re-evaluate that function here
#     456                     with torch.enable_grad():
# --> 457                         loss = float(closure())
#     458                     flat_grad = self._gather_flat_grad()
#     459                     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# <ipython-input-1-61cd00510e93> in closure()
#      32             # Calculate loss using ode_loss(t, z) function
#      33             total_loss = ode_loss(t_train, z_pred)
# ---> 34             total_loss.backward()
#      35             return total_loss
#      36
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     579                 inputs=inputs,
#     580             )
# --> 581         torch.autograd.backward(
#     582             self, gradient, retain_graph, create_graph, inputs=inputs
#     583         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     823         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824     try:
# --> 825         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826             t_outputs, *args, **kwargs
#     827         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:
