# %%
# !pip install --upgrade --force-reinstall numpy matplotlib torch pandas pykan jax scikit-learn polars

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from kan import MultKAN

EPOCHS = 300

def train_model_with_physics(model, epochs, optimizer, t_train, ode_loss, patience=50):
    # Set model to training mode
    model.train()

    best_loss = float('inf')
    counter = 0
    losses = []

    for epoch in range(epochs):
        def closure():
            optimizer.zero_grad()

            # Get model prediction (z(t))
            z_pred = model(t_train)

            # Calculate loss using ode_loss(t, z) function
            total_loss = ode_loss(t_train, z_pred)
            total_loss.backward()
            return total_loss

        loss = optimizer.step(closure)

        if loss.item() < best_loss:
            best_loss = loss.item()
            counter = 0
        else:
            counter += 1
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            break

        # Log and store loss
        if epoch % 10 == 0:
            print(f"Epoch {epoch}/{epochs}, Loss: {loss.item()}")
        losses.append(loss.item())

    # Plot loss curve
    plt.plot(losses)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training Loss Curve')
    plt.grid(True)
    plt.show()

    return model

def solve_example1(architecture):
    # Initial condition values (y(a) = A | y(0) = 1)
    A = 1
    a = 0

    # Define model
    model = MultKAN(width=architecture, grid=25, k=3, device='cpu')

    # Function for calculating loss
    # dy(t)/dt = f(t,y); => yt(t) = A + (t-a)z(t); z(t) - model output
    # Error = ((dyt(t)/dt - f(t,y))**2)/2
    def ode_loss(t, z):
        # Compute trial solution y
        y = A + (t - a) * z

        # Calculate dz(t)/dt using autograd
        dz_dt = torch.autograd.grad(z, t, grad_outputs=torch.ones_like(z), create_graph=True)[0]

        # Substitute into dy/dt = z(t) + (t - a) * dz(t)/dt
        dy_dt = z + (t - a) * dz_dt

        # Formulate the residual with dy/dt_actual
        f_term = (t + ((1 + 3 * t**2) / (1 + t + t**3))) * y
        g_term = 2 * t + t**3 + t**2 * ((1 + 3 * t**2) / (1 + t + t**3))
        return torch.mean(((dy_dt - (g_term - f_term))**2))/2

    # Training data
    t_train = torch.linspace(0, 1, 200).reshape(-1, 1).requires_grad_()

    # Define optimizer
    optimizer = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=20, tolerance_grad=1e-7, tolerance_change=1e-9, history_size=50)

    # Train model
    model = train_model_with_physics(model, epochs=EPOCHS, optimizer=optimizer, t_train=t_train, ode_loss=ode_loss)

    # Evaluate and plot
    t_eval = torch.linspace(0, 1, 200).reshape(-1, 1).requires_grad_()
    y_pred = A + (t_eval - a) * model(t_eval).detach()
    y_pred = y_pred.detach().numpy()
    t_eval_np = t_eval.detach().numpy()
    y_exact_eval = (np.exp(-t_eval_np**2 / 2) + t_eval_np**5 + t_eval_np**3 + t_eval_np**2) / (t_eval_np**3 + t_eval_np + 1)
    print(f"MSE for example 1: {(torch.sum((torch.tensor(y_exact_eval) - y_pred)**2))/200}")
    print(f"MAE for example 1: {(torch.sum((torch.abs(torch.tensor(y_exact_eval) - y_pred))))/200}")


    return t_eval_np, y_pred, y_exact_eval

def solve_example2(architecture):
    # Initial condition values (y(a) = A | y(0) = 3)
    A = 3
    a = 0

    # Define model
    model = MultKAN(width=architecture, grid=25, k=3, device='cpu')

    # Function for calculating loss
    # dy(t)/dt = f(t,y); => yt(t) = A + (t-a)z(t); z(t) - model output
    # Error = ((dyt(t)/dt - f(t,y))**2)/2
    def ode_loss(t, z):
        # Compute trial solution y
        y = A + (t - a) * z

        # Calculate dz(t)/dt using autograd
        dz_dt = torch.autograd.grad(z, t, grad_outputs=torch.ones_like(z), create_graph=True)[0]

        # Substitute into dy/dt = z(t) + (t - a) * dz(t)/dt
        dy_dt = z + (t - a) * dz_dt

        # Formulate the residual with dy/dt_actual
        f_term = 2 * y
        g_term = torch.cos(4 * t)
        return torch.mean(((dy_dt - (g_term - f_term))**2))/2

    # Training data
    t_train = torch.linspace(0, 1, 200).reshape(-1, 1).requires_grad_()

    # Define optimizer
    optimizer = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=20, tolerance_grad=1e-7, tolerance_change=1e-9, history_size=50)

    # Train model
    model = train_model_with_physics(model, epochs=EPOCHS, optimizer=optimizer, t_train=t_train, ode_loss=ode_loss)

    # Evaluate and plot
    t_eval = torch.linspace(0, 1, 200).reshape(-1, 1).requires_grad_()
    y_pred = A + (t_eval - a) * model(t_eval).detach()
    y_pred = y_pred.detach().numpy()
    t_eval_np = t_eval.detach().numpy()
    y_exact_eval = (np.sin(4 * t_eval_np) / 5 + np.cos(4 * t_eval_np) / 10 + 2.9 * np.exp(-2 * t_eval_np))
    print(f"MSE for example 2: {(torch.sum((torch.tensor(y_exact_eval) - y_pred)**2))/200}")
    print(f"MAE for example 2: {(torch.sum((torch.abs(torch.tensor(y_exact_eval) - y_pred))))/200}")


    return t_eval_np, y_pred, y_exact_eval

def solve_example3(architecture):
    # Initial condition values (y(a) = A | y(0) = 0.5)
    A = 0.5
    a = 0

    # Define model
    model = MultKAN(width=architecture, grid=25, k=3, device='cpu')

    # Function for calculating loss
    # dy(t)/dt = f(t,y); => yt(t) = A + (t-a)z(t); z(t) - model output
    # Error = ((dyt(t)/dt - f(t,y))**2)/2
    def ode_loss(t, z):
        # Compute trial solution y
        y = A + (t - a) * z

        # Calculate dz(t)/dt using autograd
        dz_dt = torch.autograd.grad(z, t, grad_outputs=torch.ones_like(z), create_graph=True)[0]

        # Substitute into dy/dt = z(t) + (t - a) * dz(t)/dt
        dy_dt = z + (t - a) * dz_dt

        # Formulate the residual with dy/dt_actual
        f_term = y - t**2 + 1
        return torch.mean(((dy_dt - f_term)**2))/2

    # Training data
    t_train = torch.linspace(0, 1, 200).reshape(-1, 1).requires_grad_()

    # Define optimizer
    optimizer = torch.optim.LBFGS(model.parameters(), lr=0.01, max_iter=20, tolerance_grad=1e-7, tolerance_change=1e-9, history_size=50)

    # Train model
    model = train_model_with_physics(model, epochs=EPOCHS, optimizer=optimizer, t_train=t_train, ode_loss=ode_loss)

    # Evaluate and plot
    t_eval = torch.linspace(0, 1, 200).reshape(-1, 1).requires_grad_()
    y_pred = A + (t_eval - a) * model(t_eval).detach()
    y_pred = y_pred.detach().numpy()
    t_eval_np = t_eval.detach().numpy()
    y_exact_eval = (t_eval_np + 1)**2 - 0.5 * np.exp(t_eval_np)
    print(f"MSE for example 3: {(torch.sum((torch.tensor(y_exact_eval) - y_pred)**2))/200}")
    print(f"MAE for example 3: {(torch.sum((torch.abs(torch.tensor(y_exact_eval) - y_pred))))/200}")


    return t_eval_np, y_pred, y_exact_eval

def plot_results(t1, y1, y1_exact, t2, y2, y2_exact, t3, y3, y3_exact, architecture):
    print("Results for architecture: ", architecture)
    plt.figure(figsize=(18, 5))

    # Plot Example 1
    plt.subplot(1, 3, 1)
    plt.plot(t1, y1, 'b-', label='KAN Solution')
    plt.plot(t1, y1_exact, 'g--', label='Exact Solution')
    plt.title('Example 1: Solution')
    plt.xlabel('t')
    plt.ylabel('y(t)')
    plt.grid(True)
    plt.legend()

    # Plot Example 2
    plt.subplot(1, 3, 2)
    plt.plot(t2, y2, 'r-', label='KAN Solution')
    plt.plot(t2, y2_exact, 'g--', label='Exact Solution')
    plt.title('Example 2: Solution')
    plt.xlabel('t')
    plt.ylabel('y(t)')
    plt.grid(True)
    plt.legend()

    # Plot Example 3
    plt.subplot(1, 3, 3)
    plt.plot(t3, y3, 'm-', label='KAN Solution')
    plt.plot(t3, y3_exact, 'c--', label='Exact Solution')
    plt.title('Example 3: Solution')
    plt.xlabel('t')
    plt.ylabel('y(t)')
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

def main():
    architectures = [ # More to be added later for optimization tests
        [1, 20, 1],
    ]
    for architecture in architectures:
        print("Solving Example 1...")
        t1, y1, y1_exact = solve_example1(architecture)

        print("Solving Example 2...")
        t2, y2, y2_exact = solve_example2(architecture)

        print("Solving Example 3...")
        t3, y3, y3_exact = solve_example3(architecture)

        print("Plotting results...")
        plot_results(t1, y1, y1_exact, t2, y2, y2_exact, t3, y3, y3_exact, architecture)


if __name__ == "__main__":
    main()
# Out:
# Solving Example 1...
# checkpoint directory created: ./model
# saving model version 0.0
# Epoch 0/300, Loss: 0.3187507390975952
# Epoch 10/300, Loss: 0.0016621161485090852
# Epoch 20/300, Loss: 5.707828313461505e-05
# Epoch 30/300, Loss: 2.1395642306742957e-06
# Epoch 40/300, Loss: 8.488833032060938e-07
# Epoch 50/300, Loss: 8.402431603826699e-07
# Epoch 60/300, Loss: 8.331912226822169e-07
# Epoch 70/300, Loss: 8.274258789242595e-07
# Epoch 80/300, Loss: 8.226880936490488e-07
# Epoch 90/300, Loss: 8.187909656953707e-07
# Epoch 100/300, Loss: 8.155832347256364e-07
# Epoch 110/300, Loss: 8.128970421239501e-07
# Epoch 120/300, Loss: 8.106624704851129e-07
# Epoch 130/300, Loss: 8.087678224910633e-07
# Epoch 140/300, Loss: 8.071909292084456e-07
# Epoch 150/300, Loss: 8.058434559643501e-07
# Epoch 160/300, Loss: 8.046761195146246e-07
# Epoch 170/300, Loss: 8.037106340452738e-07
# Epoch 180/300, Loss: 8.028483762245742e-07
# Epoch 190/300, Loss: 8.02108047537331e-07
# Epoch 200/300, Loss: 8.014581567294954e-07
# Epoch 210/300, Loss: 8.00886994056782e-07
# Epoch 220/300, Loss: 8.003662514965981e-07
# Epoch 230/300, Loss: 7.999241802281176e-07
# Epoch 240/300, Loss: 7.995149644557387e-07
# Epoch 250/300, Loss: 7.99161568920681e-07
# Epoch 260/300, Loss: 7.98819371539139e-07
# Epoch 270/300, Loss: 7.985188403836219e-07
# Epoch 280/300, Loss: 7.982501983860857e-07
# Epoch 290/300, Loss: 7.979860470186395e-07
# <ipython-input-13-7314a89aac1a>:95: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"MSE for example 1: {(torch.sum((torch.tensor(y_exact_eval) - y_pred)**2))/200}")
# <ipython-input-13-7314a89aac1a>:96: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"MAE for example 1: {(torch.sum((torch.abs(torch.tensor(y_exact_eval) - y_pred))))/200}")
# MSE for example 1: 3.463134778947108e-10
# MAE for example 1: 1.5681684089940973e-05
# Solving Example 2...
# checkpoint directory created: ./model
# saving model version 0.0
# Epoch 0/300, Loss: 19.624713897705078
# Epoch 10/300, Loss: 0.043359316885471344
# Epoch 20/300, Loss: 0.0016831479733809829
# Epoch 30/300, Loss: 7.757861749269068e-05
# Epoch 40/300, Loss: 1.4114466466708109e-05
# Epoch 50/300, Loss: 6.435252544179093e-06
# Epoch 60/300, Loss: 2.5959657250496093e-06
# Epoch 70/300, Loss: 2.3694483388680965e-06
# Epoch 80/300, Loss: 2.3620227693754714e-06
# Epoch 90/300, Loss: 2.3560655790788587e-06
# Epoch 100/300, Loss: 2.351143621126539e-06
# Epoch 110/300, Loss: 2.3473903638659976e-06
# Epoch 120/300, Loss: 2.344086396988132e-06
# Epoch 130/300, Loss: 2.3416591830027755e-06
# Epoch 140/300, Loss: 2.3394404706778005e-06
# Epoch 150/300, Loss: 2.3379113827104447e-06
# Epoch 160/300, Loss: 2.3364057142316597e-06
# Epoch 170/300, Loss: 2.3352031348622404e-06
# Epoch 180/300, Loss: 2.3342520307778614e-06
# Epoch 190/300, Loss: 2.333389602426905e-06
# Epoch 200/300, Loss: 2.332750227651559e-06
# Epoch 210/300, Loss: 2.3321397293329937e-06
# Epoch 220/300, Loss: 2.3316342776524834e-06
# Epoch 230/300, Loss: 2.3311904442380182e-06
# Epoch 240/300, Loss: 2.3307150058826664e-06
# Epoch 250/300, Loss: 2.3302770841837628e-06
# Epoch 260/300, Loss: 2.3299630811379757e-06
# Epoch 270/300, Loss: 2.3295622213481693e-06
# Epoch 280/300, Loss: 2.3293459889828227e-06
# Epoch 290/300, Loss: 2.329079279661528e-06
# <ipython-input-13-7314a89aac1a>:142: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"MSE for example 2: {(torch.sum((torch.tensor(y_exact_eval) - y_pred)**2))/200}")
# <ipython-input-13-7314a89aac1a>:143: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"MAE for example 2: {(torch.sum((torch.abs(torch.tensor(y_exact_eval) - y_pred))))/200}")
# MSE for example 2: 3.995671016276958e-10
# MAE for example 2: 1.5304833141271956e-05
# Solving Example 3...
# checkpoint directory created: ./model
# saving model version 0.0
# Epoch 0/300, Loss: 0.7111968994140625
# Epoch 10/300, Loss: 0.00044841598719358444
# Epoch 20/300, Loss: 4.87844408780802e-06
# Epoch 30/300, Loss: 1.3142205261829076e-06
# Epoch 40/300, Loss: 1.2813820831070188e-06
# Epoch 50/300, Loss: 1.273990733352548e-06
# Epoch 60/300, Loss: 1.2678299299295759e-06
# Epoch 70/300, Loss: 1.262686282643699e-06
# Epoch 80/300, Loss: 1.2583136594912503e-06
# Epoch 90/300, Loss: 1.2544961691673961e-06
# Epoch 100/300, Loss: 1.2512339253589744e-06
# Epoch 110/300, Loss: 1.2483579894251307e-06
# Epoch 120/300, Loss: 1.2458443734431057e-06
# Epoch 130/300, Loss: 1.2435816643119324e-06
# Epoch 140/300, Loss: 1.241555878550571e-06
# Epoch 150/300, Loss: 1.2397492810123367e-06
# Epoch 160/300, Loss: 1.238096842826053e-06
# Epoch 170/300, Loss: 1.2365843531370047e-06
# Epoch 180/300, Loss: 1.2351929399301298e-06
# Epoch 190/300, Loss: 1.2339255590632092e-06
# Epoch 200/300, Loss: 1.2327575404924573e-06
# Epoch 210/300, Loss: 1.2316627362451982e-06
# Epoch 220/300, Loss: 1.2306329608691158e-06
# Epoch 230/300, Loss: 1.2297164175834041e-06
# Epoch 240/300, Loss: 1.2287822528378456e-06
# Epoch 250/300, Loss: 1.2279479051358066e-06
# Epoch 260/300, Loss: 1.2271656260054442e-06
# Epoch 270/300, Loss: 1.2263560620340286e-06
# Epoch 280/300, Loss: 1.2256099353180616e-06
# Epoch 290/300, Loss: 1.2249510064066271e-06
# <ipython-input-13-7314a89aac1a>:188: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"MSE for example 3: {(torch.sum((torch.tensor(y_exact_eval) - y_pred)**2))/200}")
# <ipython-input-13-7314a89aac1a>:189: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"MAE for example 3: {(torch.sum((torch.abs(torch.tensor(y_exact_eval) - y_pred))))/200}")
# MSE for example 3: 1.9878193313616066e-08
# MAE for example 3: 0.00013022363418713212
# Plotting results...
# Results for architecture:  [[1, 0], [20, 0], [1, 0]]
